# %% [markdown]
# eda를 통해 얻은 인사이트를 가지고 머신 러닝을 진행 하도록 하겠습니다.

# %%
import pandas as pd

eda_data = pd.read_csv('./data/final_0213.csv', encoding='utf-8')

eda_data.head()
# Out:
#    Unnamed: 0  출연자                                                 제목  회차  \
# 0           0  나영석              [선공개] 유퀴즈에 포위된 나영석 PD! 형이 왜 거기서 나와..?  40
# 1           1  이명진                     드라마를 위해 조셉과 거래(?) 하는 이명진PD님 |   40
# 2           2  김부연  [#유퀴즈] 41화 레전드! ′X줄(?) 타는 스카이워크′부터 ′돌아온 의자 브레이...  41
# 3           3  김유자  [#유퀴즈] 41화 레전드! ′X줄(?) 타는 스카이워크′부터 ′돌아온 의자 브레이...  41
# 4           4  김만순  [#유퀴즈] 41화 레전드! ′X줄(?) 타는 스카이워크′부터 ′돌아온 의자 브레이...  41
#
#       조회수  좋아요수  댓글수  재생시간(초) 구독자수  term  시청률   직업 성별  나이 수상여부 인지도  에피소드  \
# 0  881349  6186  224      314    0  1290  2.6  서비스  M  중년    Y   Y    40
# 1     173     1    1      109    0  1290  2.6  서비스  M  청년    N   N    40
# 2     593     4    1      394    0  1290  2.7   기타  F  중년    N   N    41
# 3     593     4    1      394    0  1290  2.7   기타  F  청년    N   N    41
# 4     593     4    1      394    0  1290  2.7   기타  F  노년    N   N    41
#
#            날짜
# 0  2019-10-22
# 1  2019-10-22
# 2  2019-10-29
# 3  2019-10-29
# ...

# %% [markdown]
# 유튜브 같은 경우 방영이 된 후 올라오는 후의 콘텐츠 이기때문에 유튜브와 관련된 컬럼을 제거 하고 시청률을 먼져 에측 합니다.
#
# 하지만 유튜브의 구독자수에 따른 시청률 변화를 확인 했으므로 구독자수는 유지 합니다.
